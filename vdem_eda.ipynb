# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
file = ('resources/v_dem_cy_full+others_v11.1.csv')

# %%
df = pd.read_csv(file, low_memory=False)
df.head(5)
# Out:
#   country_name country_text_id  country_id  year historical_date  project  \
# 0       Mexico             MEX           3  1789      1789-12-31        1
# 1       Mexico             MEX           3  1790      1790-12-31        1
# 2       Mexico             MEX           3  1791      1791-12-31        1
# 3       Mexico             MEX           3  1792      1792-12-31        1
# 4       Mexico             MEX           3  1793      1793-12-31        1
#
#    historical                  histname  codingstart  codingend  ...  \
# 0           1  Viceroyalty of New Spain         1789       2020  ...
# 1           1  Viceroyalty of New Spain         1789       2020  ...
# 2           1  Viceroyalty of New Spain         1789       2020  ...
# 3           1  Viceroyalty of New Spain         1789       2020  ...
# 4           1  Viceroyalty of New Spain         1789       2020  ...
#
#    e_miurbpop  e_pefeliex  e_peinfmor  e_pelifeex  e_pematmor  e_wb_pop  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27192 entries, 0 to 27191
# Columns: 4176 entries, country_name to e_pt_coup
# dtypes: float64(4130), int64(17), object(29)
# memory usage: 866.3+ MB

# %%
df.describe()
# Out:
#          country_id          year       project    historical   codingstart  \
# count  27192.000000  27192.000000  27192.000000  27192.000000  27192.000000
# mean     107.185459   1927.171300      0.416998      0.613195   1842.236320
# std       82.403403     63.991882      0.593960      0.487027     58.006255
# min        3.000000   1789.000000      0.000000      0.000000   1789.000000
# 25%       46.000000   1879.000000      0.000000      0.000000   1789.000000
# 50%       91.000000   1937.000000      0.000000      1.000000   1815.000000
# 75%      155.000000   1981.000000      1.000000      1.000000   1900.000000
# max      373.000000   2020.000000      2.000000      1.000000   2011.000000
#
#           codingend  codingstart_contemp  codingend_contemp  codingstart_hist  \
# count  27192.000000         25802.000000       25802.000000      16674.000000
# mean    2011.600213          1906.055073        2019.450740       1799.129363
# ...

# %%
df['country_name'].unique()
